# %% [markdown]
# ## Import Required Packages

# %%
import pandas as pd
import numpy as np
import os
import random
# Out:
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Set Random Seed

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(1026)

# %% [markdown]
# ## Prepare Data

# %%
df = pd.DataFrame({
    "continuous_var":np.random.random(10).round(2) * 100,
    "discrete_var":np.random.randint(1,4,size=10)
})
df['discrete_var'] = df['discrete_var'].map({1:'A', 2:'B', 3:'C'})

# %%
df
# Out:
#    continuous_var discrete_var
# 0            35.0            B
# 1            84.0            B
# 2            96.0            C
# 3            19.0            A
# 4            39.0            C
# 5            29.0            B
# 6            69.0            C
# 7             8.0            B
# 8             4.0            B
# 9            84.0            B

# %% [markdown]
# ## Continuous Variables

# %% [markdown]
# ### Binning Features

# %%
df['continuous_var_bin'] = pd.cut(df['continuous_var'], 10, labels=False)

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin
# 0            35.0            B                   3
# 1            84.0            B                   8
# 2            96.0            C                   9
# 3            19.0            A                   1
# 4            39.0            C                   3
# 5            29.0            B                   2
# 6            69.0            C                   7
# 7             8.0            B                   0
# 8             4.0            B                   0
# 9            84.0            B                   8

# %% [markdown]
# ### box-cox Transformation

# %%
import scipy.stats as st

df['continuous_var_box-cox'], _ = st.boxcox(df['continuous_var'])

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570

# %% [markdown]
# #### log Transformation

# %%
df['continuous_var_log1p'] = np.log1p(df['continuous_var'])

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p
# 0              3.583519
# 1              4.442651
# 2              4.574711
# 3              2.995732
# 4              3.688879
# 5              3.401197
# 6              4.248495
# 7              2.197225
# 8              1.609438
# 9              4.442651

# %%
# Inverse Operation: np.expm1
np.expm1(df['continuous_var_log1p']) - df['continuous_var']
# Out:
# 0    0.000000e+00
# 1    1.421085e-14
# 2    0.000000e+00
# 3   -3.552714e-15
# 4    0.000000e+00
# 5    7.105427e-15
# 6    2.842171e-14
# 7    1.776357e-15
# 8   -4.440892e-16
# 9    1.421085e-14
# dtype: float64

# %% [markdown]
# ### Ranking Features

# %%
df['continuous_var_rank'] = df['continuous_var'].rank()

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p  continuous_var_rank
# 0              3.583519                  5.0
# 1              4.442651                  8.5
# 2              4.574711                 10.0
# 3              2.995732                  3.0
# 4              3.688879                  6.0
# 5              3.401197                  4.0
# 6              4.248495                  7.0
# 7              2.197225                  2.0
# 8              1.609438                  1.0
# 9              4.442651                  8.5

# %% [markdown]
# ## Discrete Variables

# %% [markdown]
# ### Count Features

# %%
df['discrete_var_count'] = df.groupby(['discrete_var'])['discrete_var'].transform('count')

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p  continuous_var_rank  discrete_var_count
# 0              3.583519                  5.0                   6
# 1              4.442651                  8.5                   6
# 2              4.574711                 10.0                   3
# 3              2.995732                  3.0                   1
# 4              3.688879                  6.0                   3
# 5              3.401197                  4.0                   6
# 6              4.248495                  7.0                   3
# 7              2.197225                  2.0                   6
# 8              1.609438                  1.0                   6
# 9              4.442651                  8.5                   6

# %% [markdown]
# ### Ranking Features for Discrete Variables

# %%
df['discrete_var_rank'] = df['discrete_var'].map({'A':1, 'B':2, 'C':3})

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p  continuous_var_rank  discrete_var_count  \
# 0              3.583519                  5.0                   6
# 1              4.442651                  8.5                   6
# 2              4.574711                 10.0                   3
# 3              2.995732                  3.0                   1
# 4              3.688879                  6.0                   3
# 5              3.401197                  4.0                   6
# 6              4.248495                  7.0                   3
# 7              2.197225                  2.0                   6
# 8              1.609438                  1.0                   6
# 9              4.442651                  8.5                   6
#
#    discrete_var_rank
# 0                  2
# 1                  2
# 2                  3
# 3                  1
# 4                  3
# 5                  2
# 6                  3
# 7                  2
# 8                  2
# 9                  2

# %% [markdown]
# ### label-encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['discrete_var_LabelEncoder'] = le.fit_transform(df['discrete_var'])

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p  continuous_var_rank  discrete_var_count  \
# 0              3.583519                  5.0                   6
# 1              4.442651                  8.5                   6
# 2              4.574711                 10.0                   3
# 3              2.995732                  3.0                   1
# 4              3.688879                  6.0                   3
# 5              3.401197                  4.0                   6
# 6              4.248495                  7.0                   3
# 7              2.197225                  2.0                   6
# 8              1.609438                  1.0                   6
# 9              4.442651                  8.5                   6
#
#    discrete_var_rank  discrete_var_LabelEncoder
# 0                  2                          1
# 1                  2                          1
# 2                  3                          2
# 3                  1                          0
# 4                  3                          2
# 5                  2                          1
# 6                  3                          2
# 7                  2                          1
# 8                  2                          1
# 9                  2                          1

# %% [markdown]
# ### one-hot

# %%
pd.get_dummies(df['discrete_var'], prefix = 'discrete_var')
# Out:
#    discrete_var_A  discrete_var_B  discrete_var_C
# 0               0               1               0
# 1               0               1               0
# 2               0               0               1
# 3               1               0               0
# 4               0               0               1
# 5               0               1               0
# 6               0               0               1
# 7               0               1               0
# 8               0               1               0
# 9               0               1               0

# %%
df = pd.concat([df, pd.get_dummies(df['discrete_var'], prefix = 'discrete_var')], axis = 1)

# %%
df
# Out:
#    continuous_var discrete_var  continuous_var_bin  continuous_var_box-cox  \
# 0            35.0            B                   3                9.436134
# 1            84.0            B                   8               15.477570
# 2            96.0            C                   9               16.644178
# 3            19.0            A                   1                6.500577
# 4            39.0            C                   3               10.052343
# 5            29.0            B                   2                8.438842
# 6            69.0            C                   7               13.890122
# 7             8.0            B                   0                3.577364
# 8             4.0            B                   0                1.972265
# 9            84.0            B                   8               15.477570
#
#    continuous_var_log1p  continuous_var_rank  discrete_var_count  \
# 0              3.583519                  5.0                   6
# 1              4.442651                  8.5                   6
# 2              4.574711                 10.0                   3
# 3              2.995732                  3.0                   1
# 4              3.688879                  6.0                   3
# 5              3.401197                  4.0                   6
# 6              4.248495                  7.0                   3
# 7              2.197225                  2.0                   6
# 8              1.609438                  1.0                   6
# 9              4.442651                  8.5                   6
#
#    discrete_var_rank  discrete_var_LabelEncoder  discrete_var_A  \
# 0                  2                          1               0
# 1                  2                          1               0
# 2                  3                          2               0
# 3                  1                          0               1
# 4                  3                          2               0
# 5                  2                          1               0
# 6                  3                          2               0
# 7                  2                          1               0
# 8                  2                          1               0
# 9                  2                          1               0
#
#    discrete_var_B  discrete_var_C
# 0               1               0
# 1               1               0
# 2               0               1
# 3               0               0
# 4               0               1
# 5               1               0
# 6               0               1
# 7               1               0
# 8               1               0
# 9               1               0
